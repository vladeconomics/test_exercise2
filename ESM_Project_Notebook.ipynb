# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("test.csv", parse_dates=["data.obstime"])
test_data
# Out:
#        Unnamed: 0 data.obstime data.ref_area  \
# 0               1   2007-05-01            AT
# 1               2   2007-06-01            AT
# 2               3   2007-07-01            AT
# 3               4   2007-08-01            AT
# 4               5   2007-09-01            AT
# ...           ...          ...           ...
# 11917       11918   2023-09-01            U2
# 11918       11919   2023-10-01            U2
# 11919       11920   2023-11-01            U2
# 11920       11921   2023-12-01            U2
# 11921       11922   2024-01-01            U2
#
#                                               data.title  data.obsvalue
# 0      loans to corporations of up to EUR 1M (new bus...          933.0
# 1      loans to corporations of up to EUR 1M (new bus...         1099.0
# 2      loans to corporations of up to EUR 1M (new bus...         1162.0
# 3      loans to corporations of up to EUR 1M (new bus...          884.0
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11922 entries, 0 to 11921
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     11922 non-null  int64
#  1   data.obstime   11922 non-null  datetime64[ns]
#  2   data.ref_area  11922 non-null  object
#  3   data.title     11922 non-null  object
#  4   data.obsvalue  11087 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 465.8+ KB

# %%
test_data.sort_values("data.obstime")
# Out:
#        Unnamed: 0 data.obstime data.ref_area  \
# 1736         1737   2005-01-01            EE
# 3722         3723   2005-01-01            IE
# 1737         1738   2005-02-01            EE
# 2522         2523   2005-02-01            FI
# 3723         3724   2005-02-01            IE
# ...           ...          ...           ...
# 8921         8922   2024-01-01            EE
# 9521         9522   2024-01-01            FR
# 9121         9122   2024-01-01            ES
# 10921       10922   2024-01-01            MT
# 11921       11922   2024-01-01            U2
#
#                                               data.title  data.obsvalue
# 1736   loans to corporations of over EUR 1M (new busi...            NaN
# 3722   loans to corporations of over EUR 1M (new busi...         2927.0
# 1737   loans to corporations of over EUR 1M (new busi...            NaN
# 2522   loans to corporations of over EUR 1M (new busi...         1338.0
# ...

# %%
test_data.rename(columns={"Unnamed: 0":"id", "data.obstime":"Date","data.ref_area":"Reference area","data.title":"Title","data.obsvalue":"Observation Value"}, inplace=True)

# %%
test_data.isna().values.any()
# Out:
# True

# %%
test_data.groupby("Reference area").agg({"Observation Value":"isna"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kw/5qd_ld213vsbrk5sj5vdknl80000gn/T/ipykernel_5200/1772467259.py in <module>
# ----> 1 test_data.groupby("Reference area").agg({"Observation Value":"isna"})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11922 entries, 0 to 11921
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 11922 non-null  int64
#  1   Date               11922 non-null  datetime64[ns]
#  2   Reference area     11922 non-null  object
#  3   Title              11922 non-null  object
#  4   Observation Value  11087 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 465.8+ KB

# %%
test_data["Title"].unique()
# Out:
# array(['loans to corporations of up to EUR 1M (new business)',
#        'loans to corporations of over EUR 1M (new business)',
#        'HICP - Overall index'], dtype=object)

# %%
df1 = test_data[test_data["Title"]=="loans to corporations of up to EUR 1M (new business)"]

# %%
df1
# Out:
#         id       Date Reference area  \
# 0        1 2007-05-01             AT
# 1        2 2007-06-01             AT
# 2        3 2007-07-01             AT
# 3        4 2007-08-01             AT
# 4        5 2007-09-01             AT
# ...    ...        ...            ...
# 7717  7718 2023-08-01             U2
# 7718  7719 2023-09-01             U2
# 7719  7720 2023-10-01             U2
# 7720  7721 2023-11-01             U2
# 7721  7722 2023-12-01             U2
#
#                                                   Title  Observation Value
# 0     loans to corporations of up to EUR 1M (new bus...             933.00
# 1     loans to corporations of up to EUR 1M (new bus...            1099.00
# 2     loans to corporations of up to EUR 1M (new bus...            1162.00
# 3     loans to corporations of up to EUR 1M (new bus...             884.00
# 4     loans to corporations of up to EUR 1M (new bus...            1005.00
# ...

# %%
df1[df1["Reference area"]=="AT"]
# Out:
#       id       Date Reference area  \
# 0      1 2007-05-01             AT
# 1      2 2007-06-01             AT
# 2      3 2007-07-01             AT
# 3      4 2007-08-01             AT
# 4      5 2007-09-01             AT
# ..   ...        ...            ...
# 195  196 2023-08-01             AT
# 196  197 2023-09-01             AT
# 197  198 2023-10-01             AT
# 198  199 2023-11-01             AT
# 199  200 2023-12-01             AT
#
#                                                  Title  Observation Value
# 0    loans to corporations of up to EUR 1M (new bus...              933.0
# 1    loans to corporations of up to EUR 1M (new bus...             1099.0
# 2    loans to corporations of up to EUR 1M (new bus...             1162.0
# 3    loans to corporations of up to EUR 1M (new bus...              884.0
# 4    loans to corporations of up to EUR 1M (new bus...             1005.0
# ..                                                 ...                ...
# ...

# %%
df2 = test_data[test_data["Title"]=="HICP - Overall index"]

# %%
df2[df2["Reference area"]=="AT"]
# Out:
#         id       Date Reference area                 Title  Observation Value
# 7922  7923 2007-06-01             AT  HICP - Overall index                1.9
# 7923  7924 2007-07-01             AT  HICP - Overall index                2.0
# 7924  7925 2007-08-01             AT  HICP - Overall index                1.7
# 7925  7926 2007-09-01             AT  HICP - Overall index                2.1
# 7926  7927 2007-10-01             AT  HICP - Overall index                2.9
# ...    ...        ...            ...                   ...                ...
# 8117  8118 2023-09-01             AT  HICP - Overall index                5.8
# 8118  8119 2023-10-01             AT  HICP - Overall index                4.9
# 8119  8120 2023-11-01             AT  HICP - Overall index                4.9
# 8120  8121 2023-12-01             AT  HICP - Overall index                5.7
# 8121  8122 2024-01-01             AT  HICP - Overall index                4.3
#
# [200 rows x 5 columns]

# %%
df1.merge(df2,on="Date")
# Out:
#        id_x       Date Reference area_x  \
# 0         2 2007-06-01               AT
# 1         2 2007-06-01               AT
# 2         2 2007-06-01               AT
# 3         2 2007-06-01               AT
# 4         2 2007-06-01               AT
# ...     ...        ...              ...
# 78315  7722 2023-12-01               U2
# 78316  7722 2023-12-01               U2
# 78317  7722 2023-12-01               U2
# 78318  7722 2023-12-01               U2
# 78319  7722 2023-12-01               U2
#
#                                                  Title_x  Observation Value_x  \
# 0      loans to corporations of up to EUR 1M (new bus...              1099.00
# 1      loans to corporations of up to EUR 1M (new bus...              1099.00
# 2      loans to corporations of up to EUR 1M (new bus...              1099.00
# 3      loans to corporations of up to EUR 1M (new bus...              1099.00
# 4      loans to corporations of up to EUR 1M (new bus...              1099.00
# ...
